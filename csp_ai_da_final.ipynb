# %% [markdown]
# <h5> Solving a CSP Problem for scheuling exams for students of a class(70 students) where every student has 3 classes out of 40 subjects, and the exam can be on any of the following 5 days: Monday, Tuesday, Wednesday, Thursday, Friday. </h5>

# %%
import random
from constraint import Problem,BacktrackingSolver

# %% [markdown]
# Number of available subjects are chosen as 40, as any number below that generates a solution ony when the domain is set as the eniter week (i.e. 7)

# %%
# Constants like Variables and Domain
SUBJECTS = [str(i) for i in range(400)]
DAYS = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday' ]
NUM_STUDENTS = 1000

# %%
# Generate random student schedules
def generate_student_schedules(num_students, subjects, subjects_per_student=3):
    return [random.sample(subjects, subjects_per_student) for _ in range(num_students)]

# Generate student schedules
student_schedules = generate_student_schedules(NUM_STUDENTS, SUBJECTS)
print(student_schedules)
# Out:
# [['370', '210', '211'], ['216', '233', '37'], ['205', '309', '327'], ['286', '303', '277'], ['100', '94', '249'], ['304', '384', '40'], ['66', '30', '335'], ['385', '277', '187'], ['313', '195', '339'], ['304', '171', '353'], ['10', '188', '220'], ['343', '253', '312'], ['373', '11', '47'], ['357', '262', '107'], ['49', '288', '195'], ['134', '326', '160'], ['272', '142', '256'], ['197', '33', '83'], ['282', '330', '63'], ['177', '243', '36'], ['33', '74', '141'], ['312', '387', '325'], ['323', '38', '166'], ['319', '306', '2'], ['386', '276', '235'], ['38', '315', '50'], ['37', '349', '85'], ['92', '383', '94'], ['280', '117', '364'], ['174', '75', '53'], ['263', '234', '396'], ['191', '33', '0'], ['253', '211', '70'], ['224', '162', '118'], ['399', '24', '391'], ['30', '208', '274'], ['224', '214', '131'], ['396', '320', '207'], ['127', '45', '137'], ['303', '295', '353'], ['392', '300', '363'], ['130', '183', '358'], ['272', '193', '249'], ['42', '235', '105'], ['338', '127', '348'], ['333', '18', '318'], ['113', '398', '52'], ['179', '277', '385'], ['267', '314', '148'], ['272', '302', '196'], ['198', '299', '382'], ['393', '235', '111'], ['98', '381', '267'], ['287', '158', '57'], ['387', '158', '300'], ['332', '359', '47'], ['95', '181', '119'], ['143', '180', '59'], ['24', '348', '340'], ['68', '290', '398'], ['124', '193', '94'], ['386', '90', '325'], ['150', '189', '348'], ['194', '162', '326'], ['20', '388', '261'], ['293', '166', '202'], ['168', '84', '158'], ['14', '68', '379'], ['123', '54', '98'], ['254', '242', '296'], ['255', '240', '50'], ['364', '259', '395'], ['388', '108', '280'], ['256', '370', '346'], ['223', '62', '284'], ['170', '239', '118'], ['51', '118', '81'], ['282', '200', '340'], ['242', '228', '347'], ['394', '245', '295'], ['67', '332', '64'], ['109', '206', '244'], ['59', '337', '238'], ['177', '237', '271'], ['311', '101', '97'], ['164', '341', '322'], ['391', '379', '299'], ['2', '239', '175'], ['147', '203', '111'], ['324', '196', '273'], ['121', '126', '113'], ['127', '316', '244'], ['231', '196', '356'], ['39', '274', '123'], ['301', '208', '373'], ['36', '207', '133'], ['172', '128', '315'], ['285', '106', '384'], ['234', '145', '221'], ['23', '380', '370'], ['118', '383', '96'], ['134', '119', '291'], ['51', '360', '285'], ['127', '239', '395'], ['63', '241', '57'], ['391', '10', '121'], ['398', '152', '399'], ['197', '284', '287'], ['399', '290', '72'], ['123', '290', '55'], ['132', '262', '30'], ['199', '226', '289'], ['72', '132', '195'], ['232', '394', '144'], ['28', '315', '235'], ['279', '368', '52'], ['170', '172', '57'], ['111', '293', '11'], ['67', '185', '299'], ['94', '348', '257'], ['4', '68', '91'], ['279', '67', '70'], ['94', '188', '238'], ['262', '83', '234'], ['15', '342', '139'], ['124', '263', '60'], ['223', '186', '342'], ['240', '396', '185'], ['286', '78', '133'], ['301', '76', '134'], ['172', '342', '17'], ['95', '148', '270'], ['348', '378', '131'], ['395', '28', '309'], ['389', '3', '210'], ['280', '314', '229'], ['68', '286', '351'], ['289', '78', '82'], ['268', '198', '162'], ['87', '346', '144'], ['396', '309', '388'], ['32', '9', '380'], ['254', '104', '135'], ['230', '360', '224'], ['67', '179', '207'], ['27', '37', '243'], ['49', '169', '356'], ['32', '14', '151'], ['234', '364', '191'], ['42', '45', '380'], ['234', '26', '258'], ['233', '23', '73'], ['91', '169', '325'], ['100', '391', '145'], ['192', '337', '210'], ['334', '19', '281'], ['116', '265', '153'], ['136', '236', '153'], ['116', '393', '278'], ['241', '160', '291'], ['231', '347', '289'], ['80', '62', '289'], ['112', '256', '59'], ['63', '85', '174'], ['156', '174', '374'], ['14', '244', '62'], ['364', '113', '12'], ['4', '362', '16'], ['75', '68', '129'], ['83', '172', '264'], ['153', '16', '260'], ['234', '83', '201'], ['97', '208', '102'], ['159', '27', '224'], ['38', '151', '250'], ['378', '153', '36'], ['68', '227', '139'], ['77', '14', '48'], ['359', '166', '38'], ['87', '370', '325'], [ ...

# %% [markdown]
# Note: The BackTackingSolver() applies a mix of degree heuristic and MRV by default.

# %%
# Create the CSP problem
problem = Problem(BacktrackingSolver())

# %%
# Add variables (subjects) and their domains (days)
for subject in SUBJECTS:
    problem.addVariable(subject, DAYS)

# Add constraint: No student should have two exams on the same day
def no_conflict(subject1, subject2):
    def constraint(day1, day2):
        for schedule in student_schedules:
            if subject1 in schedule and subject2 in schedule:
                if day1 == day2:
                    return False
        return True
    return constraint

# Add constraints for each pair of subjects
for i, subject1 in enumerate(SUBJECTS):
    for subject2 in SUBJECTS[i+1:]:
        problem.addConstraint(no_conflict(subject1, subject2), (subject1, subject2))

# %%
# Solve the problem
solution = problem.getSolution()

# Print the result
if solution:
    print("Exam Schedule:")
    for subject, day in solution.items():
        print(f"{subject}: {day}")
else:
    print("No solution found.")

# Verify the solution
def verify_solution(schedule, student_schedules):
    for student_schedule in student_schedules:
        exam_days = [schedule[subject] for subject in student_schedule]
        if len(exam_days) != len(set(exam_days)):
            return False
    return True

if solution:
    is_valid = verify_solution(solution, student_schedules)
    print(f"\nIs the solution valid? {'Yes' if is_valid else 'No'}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Solve the problem
# ----> 2 solution = problem.getSolution()
#       4 # Print the result
#       5 if solution:
#
# File d:\VIT\Sem-1\Theory\Artificial_Intelligence\CSP-sol\AI-CSP\env\Lib\site-packages\constraint\__init__.py:250, in Problem.getSolution(self)
#     248 if not domains:
#     249     return None
# --> 250 return self._solver.getSolution(domains, constraints, vconstraints)
#
# File d:\VIT\Sem-1\Theory\Artificial_Intelligence\CSP-sol\AI-CSP\env\Lib\site-packages\constraint\__init__.py:562, in BacktrackingSolver.getSolution(self, domains, constraints, vconstraints)
#     560 iter = self.getSolutionIter(domains, constraints, vconstraints)
#     561 try:
# --> 562     return next(iter)
#     563 except StopIteration:
#     564     return None
#
# File d:\VIT\Sem-1\Theory\Artificial_Intelligence\CSP-sol\AI-CSP\env\Lib\site-packages\constraint\__init__.py:544, in BacktrackingSolver.getSolutionIter(self, domains, constraints, vconstraints)
#     541         domain.pushState()
#     543 for constraint, variables in vconstraints[variable]:
# --> 544     if not constraint(variables, domains, assignments, pushdomains):
#     545         # Value is not good.
#     546         break
#     547 else:
#
# File d:\VIT\Sem-1\Theory\Artificial_Intelligence\CSP-sol\AI-CSP\env\Lib\site-packages\constraint\__init__.py:991, in FunctionConstraint.__call__(self, variables, domains, assignments, forwardcheck, _unassigned)
#     986 missing = parms.count(_unassigned)
#     987 if missing:
#     988     return (self._assigned or self._func(*parms)) and (
#     989         not forwardcheck or
#     990         missing != 1 or
# --> 991         self.forwardCheck(variables, domains, assignments)
#     992     )
#     993 return self._func(*parms)
#
# File d:\VIT\Sem-1\Theory\Artificial_Intelligence\CSP-sol\AI-CSP\env\Lib\site-packages\constraint\__init__.py:935, in Constraint.forwardCheck(self, variables, domains, assignments, _unassigned)
#     933 for value in domain[:]:
#     934     assignments[unassignedvariable] = value
# --> 935     if not self(variables, domains, assignments):
#     936         domain.hideValue(value)
#     937 del assignments[unassignedvariable]
#
# File d:\VIT\Sem-1\Theory\Artificial_Intelligence\CSP-sol\AI-CSP\env\Lib\site-packages\constraint\__init__.py:993, in FunctionConstraint.__call__(self, variables, domains, assignments, forwardcheck, _unassigned)
#     987 if missing:
#     988     return (self._assigned or self._func(*parms)) and (
#     989         not forwardcheck or
#     990         missing != 1 or
#     991         self.forwardCheck(variables, domains, assignments)
#     992     )
# --> 993 return self._func(*parms)
#
# Cell In[5], line 9, in no_conflict.<locals>.constraint(day1, day2)
#       7 def constraint(day1, day2):
#       8     for schedule in student_schedules:
# ----> 9         if subject1 in schedule and subject2 in schedule:
#      10             if day1 == day2:
#      11                 return False
#
# KeyboardInterrupt:
